# %%
from pathlib import Path
from llama_index import download_loader

SimpleCSVReader = download_loader("SimpleCSVReader")

loader = SimpleCSVReader(encoding="utf-8")
documents = loader.load_data(file=Path('./data.csv'))

# %%
type(documents)
# Out:
# list

# %%
len(documents)
# Out:
# 1

# %%
from io import StringIO

# %%
data = documents[0].text

# %%
import pandas as pd
df = pd.read_csv(StringIO(data))

# %%
df
# Out:
#       customerID   gender   SeniorCitizen  Partner  Dependents   tenure  \
# 0     7590-VHVEG   Female               0      Yes          No        1
# 1     5575-GNVDE     Male               0       No          No       34
# 2     3668-QPYBK     Male               0       No          No        2
# 3     7795-CFOCW     Male               0       No          No       45
# 4     9237-HQITU   Female               0       No          No        2
# ...          ...      ...             ...      ...         ...      ...
# 7038  6840-RESVB     Male               0      Yes         Yes       24
# 7039  2234-XADUH   Female               0      Yes         Yes       72
# 7040  4801-JZAZL   Female               0      Yes         Yes       11
# 7041  8361-LTMKD     Male               1      Yes          No        4
# 7042  3186-AJIEK     Male               0       No          No       66
#
#       PhoneService      MultipleLines  InternetService  OnlineSecurity  ...  \
# 0               No   No phone service              DSL              No  ...
# 1              Yes                 No              DSL             Yes  ...
# 2              Yes                 No              DSL             Yes  ...
# 3               No   No phone service              DSL             Yes  ...
# 4              Yes                 No      Fiber optic              No  ...
# ...            ...                ...              ...             ...  ...
# 7038           Yes                Yes              DSL             Yes  ...
# 7039           Yes                Yes      Fiber optic              No  ...
# 7040            No   No phone service              DSL             Yes  ...
# 7041           Yes                Yes      Fiber optic              No  ...
# 7042           Yes                 No      Fiber optic             Yes  ...
#
#       DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0                   No           No           No               No
# 1                  Yes           No           No               No
# 2                   No           No           No               No
# 3                  Yes          Yes           No               No
# 4                   No           No           No               No
# ...                ...          ...          ...              ...
# 7038               Yes          Yes          Yes              Yes
# 7039               Yes           No          Yes              Yes
# 7040                No           No           No               No
# 7041                No           No           No               No
# 7042               Yes          Yes          Yes              Yes
#
#              Contract  PaperlessBilling               PaymentMethod  \
# 0      Month-to-month               Yes            Electronic check
# 1            One year                No                Mailed check
# 2      Month-to-month               Yes                Mailed check
# 3            One year                No   Bank transfer (automatic)
# 4      Month-to-month               Yes            Electronic check
# ...               ...               ...                         ...
# 7038         One year               Yes                Mailed check
# 7039         One year               Yes     Credit card (automatic)
# 7040   Month-to-month               Yes            Electronic check
# 7041   Month-to-month               Yes                Mailed check
# 7042         Two year               Yes   Bank transfer (automatic)
#
#       MonthlyCharges   TotalCharges  Churn
# 0              29.85          29.85     No
# 1              56.95         1889.5     No
# 2              53.85         108.15    Yes
# 3              42.30        1840.75     No
# 4              70.70         151.65    Yes
# ...              ...            ...    ...
# 7038           84.80         1990.5     No
# 7039          103.20         7362.9     No
# 7040           29.60         346.45     No
# 7041           74.40          306.6    Yes
# 7042          105.65         6844.5     No
#
# [7043 rows x 21 columns]

# %%
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Using cached openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
# Collecting et-xmlfile (from openpyxl)
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2

# %%
from pathlib import Path
from llama_index import download_loader

PandasExcelReader = download_loader("PandasExcelReader")

loader = PandasExcelReader(pandas_config={"header": 0})
documents = loader.load_data(file=Path('./data.xlsx'))

# %%
data = documents[0].text
data
# Out:
# 'Government\nCanada\nCarretera\nnan\n1618.5\n3\n20\n32370.0\n0.0\n32370.0\n16185.0\n16185.0\n2014-01-01 00:00:00\n1\nJanuary\n2014\nGovernment\nGermany\nCarretera\nnan\n1321.0\n3\n20\n26420.0\n0.0\n26420.0\n13210.0\n13210.0\n2014-01-01 00:00:00\n1\nJanuary\n2014\nMidmarket\nFrance\nCarretera\nnan\n2178.0\n3\n15\n32670.0\n0.0\n32670.0\n21780.0\n10890.0\n2014-06-01 00:00:00\n6\nJune\n2014\nMidmarket\nGermany\nCarretera\nnan\n888.0\n3\n15\n13320.0\n0.0\n13320.0\n8880.0\n4440.0\n2014-06-01 00:00:00\n6\nJune\n2014\nMidmarket\nMexico\nCarretera\nnan\n2470.0\n3\n15\n37050.0\n0.0\n37050.0\n24700.0\n12350.0\n2014-06-01 00:00:00\n6\nJune\n2014\nGovernment\nGermany\nCarretera\nnan\n1513.0\n3\n350\n529550.0\n0.0\n529550.0\n393380.0\n136170.0\n2014-12-01 00:00:00\n12\nDecember\n2014\nMidmarket\nGermany\nMontana\nnan\n921.0\n5\n15\n13815.0\n0.0\n13815.0\n9210.0\n4605.0\n2014-03-01 00:00:00\n3\nMarch\n2014\nChannel Partners\nCanada\nMontana\nnan\n2518.0\n5\n12\n30216.0\n0.0\n30216.0\n7554.0\n22662.0\n2014-06-01 00:00:00\n6\nJune\n2014\nGovernment\nFrance\nMontana\nnan\n1899.0\n5\n20\n37980.0\n0.0\n37980.0\n18990.0\n18990.0\n2014-06-01 00:00:00\n6\nJune\n2014\nChannel Partners\nGermany\nMontana\nnan\n1545.0\n5\n12\n18540.0\n0.0\n18540.0\n4635.0\n13905.0\n2014-06-01 00:00:00\n6\nJune\n2014\nMidmarket\nMexico\nMontana\nnan\n2470.0\n5\n15\n37050.0\n0.0\n37050.0\n24700.0\n12350.0\n2014-06-01 00:00:00\n6\nJune\n2014\nEnterprise\nCanada\nMontana\nnan\n2665.5\n5\n125\n333187.5\n0.0\n333187.5\n319860.0\n13327.5\n2014-07-01 00:00:00\n7\nJuly\n2014\nSmall Business\nMexico\nMontana\nnan\n958.0\n5\n300\n287400.0\n0.0\n287400.0\n239500.0\n47900.0\n2014-08-01 00:00:00\n8\nAugust\n2014\nGovernment\nGermany\nMontana\nnan\n2146.0\n5\n7\n15022.0\n0.0\n15022.0\n10730.0\n4292.0\n2014-09-01 00:00:00\n9\nSeptember\n2014\nEnterprise\nCanada\nMontana\nnan\n345.0\n5\n125\n43125.0\n0.0\n43125.0\n41400.0\n1725.0\n2013-10-01 00:00:00\n10\nOctober\n2013\nMidmarket\nUnited States of America\nMontana\nnan\n615.0\n5\n15\n9225.0\n0.0\n9225.0\n6150.0\n3075.0\n2014-12-01 00:00:00\n12\nDecember\n2014\nGovernment\nCanada\nPaseo\nnan\n292.0\n10\n20\n5840.0\n0.0\n5840.0\n2920.0\n2920.0\n2014-02-01 00:00:00\n2\nFebruary\n2014\nMidmarket\nMexico\nPaseo\nnan\n974.0\n10\n15\n14610.0\n0.0\n14610.0\n9740.0\n4870.0\n2014-02-01 00:00:00\n2\nFebruary\n2014\nChannel Partners\nCanada\nPaseo\nnan\n2518.0\n10\n12\n30216.0\n0.0\n30216.0\n7554.0\n22662.0\n2014-06-01 00:00:00\n6\nJune\n2014\nGovernment\nGermany\nPaseo\nnan\n1006.0\n10\n350\n352100.0\n0.0\n352100.0\n261560.0\n90540.0\n2014-06-01 00:00:00\n6\nJune\n2014\nChannel Partners\nGermany\nPaseo\nnan\n367.0\n10\n12\n4404.0\n0.0\n4404.0\n1101.0\n3303.0\n2014-07-01 00:00:00\n7\nJuly\n2014\nGovernment\nMexico\nPaseo\nnan\n883.0\n10\n7\n6181.0\n0.0\n6181.0\n4415.0\n1766.0\n2014-08-01 00:00:00\n8\nAugust\n2014\nMidmarket\nFrance\nPaseo\nnan\n549.0\n10\n15\n8235.0\n0.0\n8235.0\n5490.0\n2745.0\n2013-09-01 00:00:00\n9\nSeptember\n2013\nSmall Business\nMexico\nPaseo\nnan\n788.0\n10\n300\n236400.0\n0.0\n236400.0\n197000.0\n39400.0\n2013-09-01 00:00:00\n9\nSeptember\n2013\nMidmarket\nMexico\nPaseo\nnan\n2472.0\n10\n15\n37080.0\n0.0\n37080.0\n24720.0\n12360.0\n2014-09-01 00:00:00\n9\nSeptember\n2014\nGovernment\nUnited States of America\nPaseo\nnan\n1143.0\n10\n7\n8001.0\n0.0\n8001.0\n5715.0\n2286.0\n2014-10-01 00:00:00\n10\nOctober\n2014\nGovernment\nCanada\nPaseo\nnan\n1725.0\n10\n350\n603750.0\n0.0\n603750.0\n448500.0\n155250.0\n2013-11-01 00:00:00\n11\nNovember\n2013\nChannel Partners\nUnited States of America\nPaseo\nnan\n912.0\n10\n12\n10944.0\n0.0\n10944.0\n2736.0\n8208.0\n2013-11-01 00:00:00\n11\nNovember\n2013\nMidmarket\nCanada\nPaseo\nnan\n2152.0\n10\n15\n32280.0\n0.0\n32280.0\n21520.0\n10760.0\n2013-12-01 00:00:00\n12\nDecember\n2013\nGovernment\nCanada\nPaseo\nnan\n1817.0\n10\n20\n36340.0\n0.0\n36340.0\n18170.0\n18170.0\n2014-12-01 00:00:00\n12\nDecember\n2014\nGovernment\nGermany\nPaseo\nnan\n1513.0\n10\n350\n529550.0\n0.0\n529550.0\n3933 ...

# %%
pd.read_excel(StringIO(data))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 pd.read_excel(StringIO(data))
#
# File ~/miniconda3/envs/hackathon/lib/python3.11/site-packages/pandas/io/excel/_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
#     512         "Engine should not be specified when passing "
#     513         "an ExcelFile - ExcelFile already has the engine set"
#     514     )
#
# File ~/miniconda3/envs/hackathon/lib/python3.11/site-packages/pandas/io/excel/_base.py:1567, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1563     ext = inspect_excel_format(
#    1564         content_or_path=path_or_buffer, storage_options=storage_options
#    1565     )
#    1566     if ext is None:
# -> 1567         raise ValueError(
#    1568             "Excel file format cannot be determined, you must specify "
#    1569             "an engine manually."
#    1570         )
#    1572 engine = config.get_option(f"io.excel.{ext}.reader", silent=True)
#    1573 if engine == "auto":
#
# ValueError: Excel file format cannot be determined, you must specify an engine manually.
